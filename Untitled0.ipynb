# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def get_height(node):
    if node is None:
        return 0
    return 1 + max(get_height(node.left), get_height(node.right))

def is_tree_balanced(root):
    if root is None:
        return True

    left_height = get_height(root.left)
    right_height = get_height(root.right)

    if abs(left_height - right_height) > 1:
        return False

    return is_tree_balanced(root.left) and is_tree_balanced(root.right)

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.left.left.left = Node(8)
root1 = Node(1)
root1.left = Node(2)
root1.right = Node(3)
root1.left.left = Node(4)
root1.left.right = Node(5)
root1.right.left = Node(6)
root1.left.left.left = Node(7)
root2 = Node(1)
root2.left = Node(2)
root2.right = Node(3)
root2.left.left = Node(4)
root2.left.right = Node(5)
root2.left.left.left = Node(7)

assert is_tree_balanced(root) == False
assert is_tree_balanced(root1) == True
assert is_tree_balanced(root2) == False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-ccc4367b2d82> in <cell line: 46>()
#      44 assert is_tree_balanced(root) == False
#      45 assert is_tree_balanced(root1) == True
# ---> 46 assert is_tree_balanced(root2) == True
#
# AssertionError:

# %%
context = {}
code = "def smartNumber(n):\n    def is_smart(x):\n        sum_div = 1\n        for i in range(2, x):\n            if x % i == 0:\n                sum_div += i\n        return sum_div == x\n\n    smart_numbers = []\n    num = 1\n    while len(smart_numbers) < n:\n        num += 1\n        if is_smart(num):\n            smart_numbers.append(num)\n    return smart_numbers[-1]"

exec(code, context)
print(code)
# Out:
# def smartNumber(n):
#     def is_smart(x):
#         sum_div = 1
#         for i in range(2, x):
#             if x % i == 0:
#                 sum_div += i
#         return sum_div == x
#
#     smart_numbers = []
#     num = 1
#     while len(smart_numbers) < n:
#         num += 1
#         if is_smart(num):
#             smart_numbers.append(num)
#     return smart_numbers[-1]

# %%
def smartNumber(n):
    def is_smart(x):
        sum_div = 1
        for i in range(2, x):
            if x % i == 0:
                sum_div += i
        return sum_div == x

    smart_numbers = []
    num = 1
    while len(smart_numbers) < n:
        num += 1
        if is_smart(num):
            smart_numbers.append(num)
    return smart_numbers[-1]

print(smartNumber(1))
# Out:
# 6

# %%
solution= "def breakSum(n):\n    if n < 2:\n        return n\n    max_sum = float('-inf')\n    for i in range(1, n-1):\n        for j in range(i, n-i+1):\n            k = n - i - j\n            max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))\n    return max_sum"
print(solution)
# Out:
# def breakSum(n):
#     if n < 2:
#         return n
#     max_sum = float('-inf')
#     for i in range(1, n-1):
#         for j in range(i, n-i+1):
#             k = n - i - j
#             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#     return max_sum

# %%
def search(nums, target):
    count_dict = {}
    for num in nums:
        if num in count_dict:
            count_dict[num] += 1
        else:
            count_dict[num] = 1
    for key, value in count_dict.items():
        if value == 1:
            return key
    return None
assert search([1,1,2,2,3],5) == 3
assert search([1,1,2,2,3],5) == 3
assert search([1,2,2,3,3,4,4],7) == 1

# %%
def neg_nos(nums):
    neg_nums = [num for num in nums if num < 0]
    for num in neg_nums:
        print(num)

neg_nos([-1,4,5,-6])
assert neg_nos([-1,4,5,-6]) == -1,-6
assert neg_nos([-1,-2,3,4]) == -1,-2
assert neg_nos([-7,-6,8,9]) == -7,-6
# Out:
# -1
# -6

# %%
import math

def angle_complex(real, imag):
    return math.atan2(imag, real)

assert angle_complex(0,1j)==1.5707963267948966
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-32-9aab112b74e7> in <cell line: 6>()
#       4     return math.atan2(imag, real)
#       5
# ----> 6 assert angle_complex(0,1)==1.570796326794896
#
# AssertionError:

# %%
def sum(a, b):
    common_divisors = [i for i in range(1, min(a, b)+1) if a%i == 0 and b%i == 0]
    return sum(common_divisors)
assert sum(10,15) == 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-81c3a12e7a3c> in <cell line: 4>()
#       2     common_divisors = [i for i in range(1, min(a, b)+1) if a%i == 0 and b%i == 0]
#       3     return sum(common_divisors)
# ----> 4 assert sum(10,15) == 6
#
# <ipython-input-34-81c3a12e7a3c> in sum(a, b)
#       1 def sum(a, b):
#       2     common_divisors = [i for i in range(1, min(a, b)+1) if a%i == 0 and b%i == 0]
# ----> 3     return sum(common_divisors)
#       4 assert sum(10,15) == 6
#
# TypeError: sum() missing 1 required positional argument: 'b'

# %%
def all_Bits_Unset_In_The_Given_Range(n, start, end):
    mask = ((1 << (end - start + 1)) - 1) << start
    return (n & mask) == 0

assert all_Bits_Set_In_The_Given_Range(4,1,2) == True

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

def find_adverb_position(sentence):
    tokens = nltk.word_tokenize(sentence)
    tagged = nltk.pos_tag(tokens)
    for i, (word, tag) in enumerate(tagged):
        if tag == 'RB':  # 'RB' is the Penn Treebank tag for adverbs
            return (i, i + len(word), word)
    return None  # or raise an exception, depending on your requirements

assert find_adverb_position("clearly!! we can see the sky")==(0, 7, 'clearly')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-41-d3e250e7e5b5> in <cell line: 12>()
#      10     return None  # or raise an exception, depending on your requirements
#      11
# ---> 12 assert find_adverb_position("clearly!! we can see the sky")==(0, 7, 'clearly')
#
# <ipython-input-41-d3e250e7e5b5> in find_adverb_position(sentence)
#       3
#       4 def find_adverb_position(sentence):
# ----> 5     tokens = nltk.word_tokenize(sentence)
#       6     tagged = nltk.pos_tag(tokens)
#       7     for i, (word, tag) in enumerate(tagged):
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#     108
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def get_height(node):
    if node is None:
        return 0
    return 1 + max(get_height(node.left), get_height(node.right))

def is_tree_balanced(root):
    if root is None:
        return True

    left_height = get_height(root.left)
    right_height = get_height(root.right)

    if abs(left_height - right_height) > 1:
        return False

    return is_tree_balanced(root.left) and is_tree_balanced(root.right)

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.left.left.left = Node(8)
root1 = Node(1)
root1.left = Node(2)
root1.right = Node(3)
root1.left.left = Node(4)
root1.left.right = Node(5)
root1.right.left = Node(6)
root1.left.left.left = Node(7)
root2 = Node(1)
root2.left = Node(2)
root2.right = Node(3)
root2.left.left = Node(4)
root2.left.right = Node(5)
root2.left.left.left = Node(7)

assert is_tree_balanced(root) == False
assert is_tree_balanced(root1) == True
assert is_tree_balanced(root2) == False

# %%
def text_match_two_three(text):
    pattern = r'a(b{2,3})'
    if re.fullmatch(pattern, text):
        return 'Found a match!'
    else:
        return 'Not matched!'

assert text_match_two_three("ac")==('Not matched!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8f484711f36e> in <cell line: 8>()
#       6         return 'Not matched!'
#       7
# ----> 8 assert text_match_two_three("ac")==('Not matched!')
#
# <ipython-input-2-8f484711f36e> in text_match_two_three(text)
#       1 def text_match_two_three(text):
#       2     pattern = r'a(b{2,3})'
# ----> 3     if re.fullmatch(pattern, text):
#       4         return 'Found a match!'
#       5     else:
#
# NameError: name 're' is not defined

# %%
def smartNumber(n):
    def is_smart(x):
        sum_div = 1
        for i in range(2, x):
            if x % i == 0:
                sum_div += i
        return sum_div == x

    smart_numbers = []
    num = 1
    while len(smart_numbers) < n:
        num += 1
        if is_smart(num):
            smart_numbers.append(num)
    return smart_numbers[-1]

assert smartNumber(1) == 30
assert smartNumber(50) == 273
assert smartNumber(1000) == 2664
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 1694
# 2178
# 2541
# 5082
# 7623
# 79
# 193
# 2
# 4
# 8
# 16
# 953
# 1906
# 3812
# 7624
# 3
# 13
# 17
# 23
# 39
# 51
# 69
# 221
# 299
# 391
# 663
# 897
# 1173
# 5083
# 2
# 5
# 10
# 25
# 50
# 61
# 122
# 125
# 250
# 305
# 610
# 1525
# 3050
# 7625
# 101
# 151
# 2
# 3
# 4
# 6
# 12
# 31
# 41
# 62
# 82
# 93
# 123
# 124
# 164
# 186
# 246
# 372
# 492
# 1271
# 2542
# 3813
# 5084
# 7626
# 7
# 2179
# 2
# 29
# 58
# 263
# 526
# 7627
# 3
# 5
# 9
# 15
# 27
# 45
# 113
# 135
# 339
# 565
# 1017
# 1695
# 3051
# 5085
# 2
# 4
# 8
# 1907
# 3814
# 7628
# 11
# 19
# 73
# 209
# 803
# 1387
# 2
# 3
# 6
# 2543
# 5086
# 7629
# 2
# 4
# 5
# 7
# 10
# 14
# 20
# 28
# 35
# 3
# 4
# 6
# 9
# 12
# 18
# 36
# 439
# 878
# 1317
# 1756
# 2634
# 3951
# 5268
# 7902
# 5
# 29
# 109
# 145
# 545
# 3161
# 2
# 7
# 14
# 1129
# 2258
# 7903
# 3
# 11
# 33
# 479
# 1437
# 5269
# 2
# 4
# 8
# 13
# 16
# 19
# 26
# 32
# 38
# 52
# 64
# 76
# 104
# 152
# 208
# 247
# 304
# 416
# 494
# 608
# 832
# 988
# 1216
# 1976
# 3952
# 7904
# 2
# 3
# 5
# 6
# 10
# 15
# 17
# 30
# 31
# 34
# 51
# 62
# 85
# 93
# 102
# 155
# 170
# 186
# 255
# 310
# 465
# 510
# 527
# 930
# 1054
# 1581
# 2635
# 3162
# 5270
# 7905
# 97
# 163
# 2
# 4
# 59
# 67
# 118
# 134
# 236
# 268
# 3953
# 7906
# 3
# 7
# 9
# 21
# 63
# 251
# 753
# 1757
# 2259
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-1f84a406ad09> in <cell line: 18>()
#      16     return smart_numbers[-1]
#      17
# ---> 18 assert smartNumber(50) == 273
#      19 assert smartNumber(1000) == 2664
#
# <ipython-input-5-1f84a406ad09> in smartNumber(n)
#      12     while len(smart_numbers) < n:
#      13         num += 1
# ---> 14         if is_smart(num):
#      15             smart_numbers.append(num)
#      16     return smart_numbers[-1]
#
# <ipython-input-5-1f84a406ad09> in is_smart(x)
#       3         sum_div = 1
#       4         for i in range(2, x):
# ----> 5             if x % i == 0:
#       6                 print(i)
#       7                 sum_div += i
#
# KeyboardInterrupt:

# %%
def breakSum(n):
    if n < 2:
        return n
    max_sum = float('-inf')
    for i in range(1, n-1):
        for j in range(i, n-i+1):
            k = n - i - j
            max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
    return max_sum

assert breakSum(24) == 27
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6cb07c36fa62> in <cell line: 11>()
#       9     return max_sum
#      10
# ---> 11 assert breakSum(24) == 27
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       6         for j in range(i, n-i+1):
#       7             k = n - i - j
# ----> 8             max_sum = max(max_sum, i + j + k, i + breakSum(i) + breakSum(j) + breakSum(k))
#       9     return max_sum
#      10
#
# <ipython-input-8-6cb07c36fa62> in breakSum(n)
#       1 def breakSum(n):
# ----> 2     if n < 2:
#       3         return n
#       4     max_sum = float('-inf')
#       5     for i in range(1, n-1):
#
# KeyboardInterrupt:

# %%
def binomial_Coeff(n, k):
    if k == 0 or k == n:
        return 1
    return binomial_Coeff(n - 1, k - 1) + binomial_Coeff(n - 1, k)


assert binomial_Coeff(5, 2) == 10
assert binomial_Coeff(4, 3) == 4
assert binomial_Coeff(3, 2) == 3

# %%
from google.colab import drive
drive.mount('/content/drive')
save_path = '/content/drive/My Drive/Colab Notebooks/AI_CAP/data'
# Out:
# Mounted at /content/drive

# %%
import json
import os
with open(os.path.join(save_path, 'train.json'), 'r') as f:
    lines = f.readlines()
# Parse each line as a JSON object
train_data = [json.loads(line) for line in lines]


with open(os.path.join(save_path, 'test.json'), 'r') as f:
    lines = f.readlines()
# Parse each line as a JSON object
test_data = [json.loads(line) for line in lines]

# %%
print(len(train_data[0]['code']))
print(len(test_data))
print(len(train_data))
# Out:
# 364
# 500
# 374

# %%
train_len = 0
cnt = 0
test_len =  0
for data in train_data:
    cnt +=1
    train_len += len(data['code'])
for data in test_data:
    test_len += len(data['code'])
print(train_len * 500/374)
print(test_len)
print(cnt)
# Out:
# 89191.17647058824
# 91635
# 374
