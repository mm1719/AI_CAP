# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/microsoft/Phi-3-mini-4k-instruct"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

data = query({"inputs": "Why the sky is blue?"})
print(data[0]['generated_text'])
# Out:
# Why the sky is blue?
#
# I know there are a few answers for that but I want to know what is the explanation for this at a **molecular level**, by molecular I mean the atmosphere, the air and everything else apart from the sunlight.
#
# Recently in our school we learnt about **colour** and also our primary colours Red, Yellow and Blue. Based on this we have been taught that:
#
# $$
# \text{Something that absorbs all coloured

# %%
from google.colab import drive
drive.mount('/content/drive')
save_path = '/content/drive/My Drive/Colab Notebooks/AI_CAP/data'

# %%
import json
